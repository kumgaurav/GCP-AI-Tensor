# %% [markdown]
# # duel-q-learning-agent

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
tf.compat.v1.disable_eager_execution()
sns.set()

# %%
df = pd.read_csv('/Users/gkumargaur/workspace/python/gitprojects/Stock-Prediction-Models/dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2020-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2020-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2020-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2020-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2020-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
from collections import deque
import random


class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen = 1000)
        self.inventory = []

        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999

        tf.compat.v1.reset_default_graph()
        self.sess = tf.compat.v1.InteractiveSession()
        self.X = tf.compat.v1.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.compat.v1.placeholder(tf.float32, [None, self.action_size])
        feed = tf.compat.v1.layers.dense(self.X, 512, activation = tf.nn.relu)
        tensor_action, tensor_validation = tf.split(feed,2,1)
        feed_action = tf.compat.v1.layers.dense(tensor_action, self.action_size)
        feed_validation = tf.compat.v1.layers.dense(tensor_validation, 1)
        self.logits = feed_validation + tf.subtract(feed_action,tf.reduce_mean(input_tensor=feed_action,axis=1,keepdims=True))
        self.cost = tf.reduce_mean(input_tensor=tf.square(self.Y - self.logits))
        self.optimizer = tf.compat.v1.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        self.sess.run(tf.compat.v1.global_variables_initializer())

    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0]
        )

    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def replay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost

    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)

            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))


            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )

            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest

    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)

                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]

                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]

                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest,
                                    next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size,
              window_size = window_size,
              trend = close,
              skip = skip,
              batch_size = batch_size)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# /Users/gkumargaur/opt/miniconda3/envs/tensorflow/lib/python3.8/site-packages/tensorflow/python/client/session.py:1761: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# /Users/gkumargaur/opt/miniconda3/envs/tensorflow/lib/python3.8/site-packages/tensorflow/python/keras/legacy_tf_layers/core.py:171: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   warnings.warn('`tf.layers.dense` is deprecated and '
# /Users/gkumargaur/opt/miniconda3/envs/tensorflow/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1692: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# epoch: 10, total rewards: 1062.495183.3, cost: 0.433255, total money: 3488.815129
# epoch: 20, total rewards: 1550.285222.3, cost: 0.200012, total money: 3983.475163
# epoch: 30, total rewards: 1530.455324.3, cost: 0.126911, total money: 4871.355287
# epoch: 40, total rewards: 1201.835208.3, cost: 0.096327, total money: 4542.735171
# epoch: 50, total rewards: 1422.545352.3, cost: 0.169600, total money: 4823.875369
# epoch: 60, total rewards: 1393.095401.3, cost: 0.063358, total money: 4831.225344
# epoch: 70, total rewards: 1464.775211.3, cost: 0.045651, total money: 4790.695193
# epoch: 80, total rewards: 1179.595279.3, cost: 0.035135, total money: 5430.745242
# epoch: 90, total rewards: 1110.565188.3, cost: 0.028609, total money: 5355.705141
# epoch: 100, total rewards: 1278.735173.3, cost: 0.025076, total money: 4601.355107
# epoch: 110, total rewards: 1057.285099.3, cost: 0.025078, total money: 4440.155033
# epoch: 120, total rewards: 1376.615238.3, cost: 0.015351, total money: 5621.755191
# epoch: 130, total rewards: 810.705080.3, cost: 0.017955, total money: 4135.905031
# epoch: 140, total rewards: 1018.755129.3, cost: 0.020809, total money: 4401.625063
# epoch: 150, total rewards: 987.295108.3, cost: 0.017507, total money: 4370.165042
# epoch: 160, total rewards: 952.735172.3, cost: 0.021284, total money: 4333.025089
# epoch: 170, total rewards: 1440.065127.3, cost: 0.011228, total money: 4825.435061
# epoch: 180, total rewards: 1106.525027.3, cost: 0.008563, total money: 6286.755007
# epoch: 190, total rewards: 1273.825075.3, cost: 0.007378, total money: 5525.525026
# epoch: 200, total rewards: 1389.025088.3, cost: 0.008857, total money: 7518.755068

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 2: buy 1 unit at price 762.020020, total balance 9237.979980
# day 4: buy 1 unit at price 790.510010, total balance 8447.469970
# day 6: buy 1 unit at price 762.559998, total balance 7684.909972
# day 10: buy 1 unit at price 764.479980, total balance 6920.429992
# day 11: buy 1 unit at price 771.229980, total balance 6149.200012
# day 12, sell 1 unit at price 760.539978, investment -0.194226 %, total balance 6909.739990,
# day 13: buy 1 unit at price 769.200012, total balance 6140.539978
# day 14, sell 1 unit at price 768.270020, investment -2.813372 %, total balance 6908.809998,
# day 15: buy 1 unit at price 760.989990, total balance 6147.820008
# day 16, sell 1 unit at price 761.679993, investment -0.115401 %, total balance 6909.500001,
# day 18, sell 1 unit at price 770.840027, investment 0.831944 %, total balance 7680.340028,
# day 20: buy 1 unit at price 747.919983, total balance 6932.420045
# day 22: buy 1 unit at price 762.520020, total balance 6169.900025
# day 23: buy 1 unit at price 759.109985, total balance 5410.790040
# day 24, sell 1 unit at price 771.190002, investment -0.005184 %, total balance 6181.980042,
# day 28, sell 1 unit at price 796.099976, investment 3.497135 %, total balance 6978.080018,
# day 29: buy 1 unit at price 797.070007, total balance 6181.010011
# day 32: buy 1 unit at price 794.200012, total balance 5386.809999
# day 35: buy 1 unit at price 791.260010, total balance 4595.549989
# day 37: buy 1 unit at price 791.549988, total balance 3804.000001
# day 38, sell 1 unit at price 785.049988, investment 3.161671 %, total balance 4589.049989,
# day 39, sell 1 unit at price 782.789978, investment 4.662263 %, total balance 5371.839967,
# day 41, sell 1 unit at price 786.140015, investment 3.097623 %, total balance 6157.979982,
# day 42: buy 1 unit at price 786.900024, total balance 5371.079958
# day 43, sell 1 unit at price 794.020020, investment 4.598811 %, total balance 6165.099978,
# day 45, sell 1 unit at price 806.650024, investment 1.201904 %, total balance 6971.750002,
# day 46: buy 1 unit at price 804.789978, total balance 6166.960024
# day 50: buy 1 unit at price 804.609985, total balance 5362.350039
# day 51: buy 1 unit at price 806.070007, total balance 4556.280032
# day 52: buy 1 unit at price 802.174988, total balance 3754.105044
# day 54, sell 1 unit at price 819.309998, investment 3.161670 %, total balance 4573.415042,
# day 55, sell 1 unit at price 823.869995, investment 4.121273 %, total balance 5397.285037,
# day 56, sell 1 unit at price 835.669983, investment 5.573873 %, total balance 6232.955020,
# day 63: buy 1 unit at price 801.489990, total balance 5431.465030
# day 64, sell 1 unit at price 801.340027, investment 1.835049 %, total balance 6232.805057,
# day 65: buy 1 unit at price 806.969971, total balance 5425.835086
# day 66, sell 1 unit at price 808.380005, investment 0.446082 %, total balance 6234.215091,
# day 72: buy 1 unit at price 824.159973, total balance 5410.055118
# day 73, sell 1 unit at price 828.070007, investment 2.915701 %, total balance 6238.125125,
# day 74: buy 1 unit at price 831.659973, total balance 5406.465152
# day 75: buy 1 unit at price 830.760010, total balance 4575.705142
# day 76: buy 1 unit at price 831.330017, total balance 3744.375125
# day 77: buy 1 unit at price 828.640015, total balance 2915.735110
# day 78: buy 1 unit at price 829.280029, total balance 2086.455081
# day 79: buy 1 unit at price 823.210022, total balance 1263.245059
# day 80: buy 1 unit at price 835.239990, total balance 428.005069
# day 83, sell 1 unit at price 827.780029, investment 2.693317 %, total balance 1255.785098,
# day 84, sell 1 unit at price 831.909973, investment 3.706795 %, total balance 2087.695071,
# day 85, sell 1 unit at price 835.369995, investment 4.227128 %, total balance 2923.065066,
# day 89: buy 1 unit at price 845.619995, total balance 2077.445071
# day 92: buy 1 unit at price 852.119995, total balance 1225.325076
# day 94: buy 1 unit at price 830.460022, total balance 394.865054
# day 97, sell 1 unit at price 814.429993, investment 0.924449 %, total balance 1209.295047,
# day 98: buy 1 unit at price 819.510010, total balance 389.785037
# day 99, sell 1 unit at price 820.919983, investment -0.393126 %, total balance 1210.705020,
# day 100: buy 1 unit at price 831.409973, total balance 379.295047
# day 101, sell 1 unit at price 831.500000, investment -0.019235 %, total balance 1210.795047,
# day 102, sell 1 unit at price 829.559998, investment -0.144447 %, total balance 2040.355045,
# day 104: buy 1 unit at price 834.570007, total balance 1205.785038
# day 108: buy 1 unit at price 824.729980, total balance 381.055058
# day 109, sell 1 unit at price 823.349976, investment -0.959913 %, total balance 1204.405034,
# day 110, sell 1 unit at price 824.320007, investment -0.521337 %, total balance 2028.725041,
# day 113: buy 1 unit at price 836.820007, total balance 1191.905034
# day 114, sell 1 unit at price 838.210022, investment 1.076837 %, total balance 2030.115056,
# day 120: buy 1 unit at price 874.250000, total balance 1155.865056
# day 122, sell 1 unit at price 912.570007, investment 10.855065 %, total balance 2068.435063,
# day 123: buy 1 unit at price 916.440002, total balance 1151.995061
# day 124: buy 1 unit at price 927.039978, total balance 224.955083
# day 132, sell 1 unit at price 937.080017, investment 12.192906 %, total balance 1162.035100,
# day 137: buy 1 unit at price 941.859985, total balance 220.175115
# day 138, sell 1 unit at price 948.820007, investment 12.204065 %, total balance 1168.995122,
# day 140, sell 1 unit at price 969.539978, investment 13.779747 %, total balance 2138.535100,
# day 142: buy 1 unit at price 975.880005, total balance 1162.655095
# day 144: buy 1 unit at price 966.950012, total balance 195.705083
# day 147, sell 1 unit at price 976.570007, investment 17.593861 %, total balance 1172.275090,
# day 149: buy 1 unit at price 983.409973, total balance 188.865117
# day 150, sell 1 unit at price 949.830017, investment 15.902186 %, total balance 1138.695134,
# day 151: buy 1 unit at price 942.900024, total balance 195.795110
# day 154, sell 1 unit at price 942.309998, investment 13.338789 %, total balance 1138.105108,
# day 155, sell 1 unit at price 939.780029, investment 12.606494 %, total balance 2077.885137,
# day 156, sell 1 unit at price 957.369995, investment 16.082841 %, total balance 3035.255132,
# day 157: buy 1 unit at price 950.630005, total balance 2084.625127
# day 158, sell 1 unit at price 959.450012, investment 14.654287 %, total balance 3044.075139,
# day 161: buy 1 unit at price 952.270020, total balance 2091.805119
# day 163: buy 1 unit at price 940.489990, total balance 1151.315129
# day 164: buy 1 unit at price 917.789978, total balance 233.525151
# day 167, sell 1 unit at price 911.710022, investment 4.284818 %, total balance 1145.235173,
# day 168, sell 1 unit at price 906.690002, investment -1.063899 %, total balance 2051.925175,
# day 169, sell 1 unit at price 918.590027, investment -0.911498 %, total balance 2970.515202,
# day 170: buy 1 unit at price 928.799988, total balance 2041.715214
# day 171, sell 1 unit at price 930.090027, investment -1.249650 %, total balance 2971.805241,
# day 172: buy 1 unit at price 943.830017, total balance 2027.975224
# day 173, sell 1 unit at price 947.159973, investment -2.942988 %, total balance 2975.135197,
# day 174: buy 1 unit at price 955.989990, total balance 2019.145207
# day 175: buy 1 unit at price 953.419983, total balance 1065.725224
# day 176: buy 1 unit at price 965.400024, total balance 100.325200
# day 183, sell 1 unit at price 934.090027, investment -3.398313 %, total balance 1034.415227,
# day 184: buy 1 unit at price 941.530029, total balance 92.885198
# day 186, sell 1 unit at price 930.830017, investment -5.346697 %, total balance 1023.715215,
# day 188, sell 1 unit at price 923.650024, investment -2.041574 %, total balance 1947.365239,
# day 189, sell 1 unit at price 927.960022, investment -2.384733 %, total balance 2875.325261,
# day 190, sell 1 unit at price 929.359985, investment -2.405834 %, total balance 3804.685246,
# day 191, sell 1 unit at price 926.789978, investment -1.456689 %, total balance 4731.475224,
# day 195: buy 1 unit at price 922.669983, total balance 3808.805241
# day 196, sell 1 unit at price 922.219971, investment 0.482680 %, total balance 4731.025212,
# day 197, sell 1 unit at price 926.960022, investment -0.198101 %, total balance 5657.985234,
# day 198: buy 1 unit at price 910.979980, total balance 4747.005254
# day 199, sell 1 unit at price 910.669983, investment -3.513348 %, total balance 5657.675237,
# day 200: buy 1 unit at price 906.659973, total balance 4751.015264
# day 201, sell 1 unit at price 924.690002, investment -3.274092 %, total balance 5675.705266,
# day 202: buy 1 unit at price 927.000000, total balance 4748.705266
# day 204: buy 1 unit at price 915.890015, total balance 3832.815251
# day 205: buy 1 unit at price 913.809998, total balance 2919.005253
# day 207, sell 1 unit at price 929.570007, investment -2.501518 %, total balance 3848.575260,
# day 209, sell 1 unit at price 937.340027, investment -2.906567 %, total balance 4785.915287,
# day 211: buy 1 unit at price 927.809998, total balance 3858.105289
# day 214: buy 1 unit at price 929.080017, total balance 2929.025272
# day 216: buy 1 unit at price 935.090027, total balance 1993.935245
# day 217, sell 1 unit at price 925.109985, investment -1.743975 %, total balance 2919.045230,
# day 218, sell 1 unit at price 920.289978, investment -0.257948 %, total balance 3839.335208,
# day 219, sell 1 unit at price 915.000000, investment 0.441285 %, total balance 4754.335208,
# day 222, sell 1 unit at price 932.450012, investment 2.844511 %, total balance 5686.785220,
# day 223: buy 1 unit at price 928.530029, total balance 4758.255191
# day 224, sell 1 unit at price 920.969971, investment -0.650489 %, total balance 5679.225162,
# day 226, sell 1 unit at price 944.489990, investment 3.122643 %, total balance 6623.715152,
# day 227: buy 1 unit at price 949.500000, total balance 5674.215152
# day 229: buy 1 unit at price 953.270020, total balance 4720.945132
# day 230: buy 1 unit at price 957.789978, total balance 3763.155154
# day 231, sell 1 unit at price 951.679993, investment 4.144187 %, total balance 4714.835147,
# day 232: buy 1 unit at price 969.960022, total balance 3744.875125
# day 235, sell 1 unit at price 972.599976, investment 4.827495 %, total balance 4717.475101,
# day 236: buy 1 unit at price 989.250000, total balance 3728.225101
# day 239, sell 1 unit at price 992.000000, investment 6.772289 %, total balance 4720.225101,
# day 243, sell 1 unit at price 988.200012, investment 5.679665 %, total balance 5708.425113,
# day 247, sell 1 unit at price 972.559998, investment 4.741900 %, total balance 6680.985111,
# day 250, sell 1 unit at price 1016.640015, investment 7.071092 %, total balance 7697.625126,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
