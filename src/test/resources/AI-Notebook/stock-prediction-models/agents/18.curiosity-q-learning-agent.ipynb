# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
tf.compat.v1.disable_eager_execution()
sns.set()

# %%
df = pd.read_csv('/Users/gkumargaur/workspace/python/gitprojects/Stock-Prediction-Models/dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2020-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2020-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2020-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2020-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2020-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
from collections import deque
import random

class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 500
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300

    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.compat.v1.reset_default_graph()
        self.X = tf.compat.v1.placeholder(tf.float32, (None, self.state_size))
        self.Y = tf.compat.v1.placeholder(tf.float32, (None, self.state_size))
        self.ACTION = tf.compat.v1.placeholder(tf.float32, (None))
        self.REWARD = tf.compat.v1.placeholder(tf.float32, (None))
        self.batch_size = tf.shape(input=self.ACTION)[0]

        with tf.compat.v1.variable_scope('curiosity_model'):
            action = tf.reshape(self.ACTION, (-1,1))
            state_action = tf.concat([self.X, action], axis=1)
            save_state = tf.identity(self.Y)

            feed = tf.compat.v1.layers.dense(state_action, 32, activation=tf.nn.relu)
            self.curiosity_logits = tf.compat.v1.layers.dense(feed, self.state_size)
            self.curiosity_cost = tf.reduce_sum(input_tensor=tf.square(save_state - self.curiosity_logits), axis=1)

            self.curiosity_optimizer = tf.compat.v1.train.RMSPropOptimizer(self.LEARNING_RATE)\
            .minimize(tf.reduce_mean(input_tensor=self.curiosity_cost))

        total_reward = tf.add(self.curiosity_cost, self.REWARD)

        with tf.compat.v1.variable_scope("q_model"):
            with tf.compat.v1.variable_scope("eval_net"):
                x_action = tf.compat.v1.layers.dense(self.X, 128, tf.nn.relu)
                self.logits = tf.compat.v1.layers.dense(x_action, self.OUTPUT_SIZE)

            with tf.compat.v1.variable_scope("target_net"):
                y_action = tf.compat.v1.layers.dense(self.Y, 128, tf.nn.relu)
                y_q = tf.compat.v1.layers.dense(y_action, self.OUTPUT_SIZE)

            q_target = total_reward + self.GAMMA * tf.reduce_max(input_tensor=y_q, axis=1)
            action = tf.cast(self.ACTION, tf.int32)
            action_indices = tf.stack([tf.range(self.batch_size, dtype=tf.int32), action], axis=1)
            q = tf.gather_nd(params=self.logits, indices=action_indices)
            self.cost = tf.compat.v1.losses.mean_squared_error(labels=q_target, predictions=q)
            self.optimizer = tf.compat.v1.train.RMSPropOptimizer(self.LEARNING_RATE).minimize(
            self.cost, var_list=tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES, "q_model/eval_net"))

        t_params = tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.GLOBAL_VARIABLES, scope='q_model/target_net')
        e_params = tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.GLOBAL_VARIABLES, scope='q_model/eval_net')
        self.target_replace_op = [tf.compat.v1.assign(t, e) for t, e in zip(t_params, e_params)]

        self.sess = tf.compat.v1.InteractiveSession()
        self.sess.run(tf.compat.v1.global_variables_initializer())

    def _memorize(self, state, action, reward, new_state, done):
        self.MEMORIES.append((state, action, reward, new_state, done))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)

    def predict(self, inputs):
        return self.sess.run(self.logits, feed_dict={self.X:inputs})

    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        actions = np.array([a[1] for a in replay])
        rewards = np.array([a[2] for a in replay])
        new_states = np.array([a[3] for a in replay])
        if (self.T_COPY + 1) % self.COPY == 0:
            self.sess.run(self.target_replace_op)

        cost, _ = self.sess.run([self.cost, self.optimizer], feed_dict = {
            self.X: states, self.Y: new_states, self.ACTION: actions, self.REWARD: rewards
        })

        if (self.T_COPY + 1) % self.COPY == 0:
            self.sess.run(self.curiosity_optimizer, feed_dict = {
                self.X: states, self.Y: new_states, self.ACTION: actions, self.REWARD: rewards
            })
        return cost

    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)

            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))

            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )

            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest

    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):

                action = self._select_action(state)
                next_state = self.get_state(t + 1)

                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]

                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]

                invest = ((starting_money - initial_money) / initial_money)

                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                state = next_state
                replay = random.sample(self.MEMORIES, batch_size)
                cost = self._construct_memories(replay)
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size,
              window_size = window_size,
              trend = close,
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From /Users/gkumargaur/opt/miniconda3/envs/tensorflow/lib/python3.8/site-packages/tensorflow/python/training/rmsprop.py:123: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# /Users/gkumargaur/opt/miniconda3/envs/tensorflow/lib/python3.8/site-packages/tensorflow/python/keras/legacy_tf_layers/core.py:171: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   warnings.warn('`tf.layers.dense` is deprecated and '
# /Users/gkumargaur/opt/miniconda3/envs/tensorflow/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1692: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# epoch: 10, total rewards: 420.039920.3, cost: 134798.078125, total money: 10420.039920
# epoch: 20, total rewards: 1660.430048.3, cost: 4333091.000000, total money: 3903.410028
# epoch: 30, total rewards: 1611.420227.3, cost: 236008.593750, total money: 5680.900208
# epoch: 40, total rewards: 514.429868.3, cost: 1176723.500000, total money: 8478.519833
# epoch: 50, total rewards: 972.149965.3, cost: 464403.156250, total money: 303.229981
# epoch: 60, total rewards: 128.610043.3, cost: 348360.750000, total money: 8092.700008
# epoch: 70, total rewards: 1015.434932.3, cost: 836516.625000, total money: 8981.684932
# epoch: 80, total rewards: 795.815305.3, cost: 1150839.500000, total money: 7837.695310
# epoch: 90, total rewards: 774.975219.3, cost: 532586.187500, total money: 4879.155272
# epoch: 100, total rewards: 1305.459782.3, cost: 794336.375000, total money: 10288.819767
# epoch: 110, total rewards: 499.914733.3, cost: 15736621.000000, total money: 5528.944701
# epoch: 120, total rewards: 1846.649784.3, cost: 701888.750000, total money: 532.209720
# epoch: 130, total rewards: 1677.235174.3, cost: 1272412.750000, total money: 2913.805121
# epoch: 140, total rewards: 1425.265324.3, cost: 853023.750000, total money: 8499.805302
# epoch: 150, total rewards: 1020.049931.3, cost: 4472978.000000, total money: 1320.819950
# epoch: 160, total rewards: 1613.719849.3, cost: 755225.750000, total money: 3868.569885
# epoch: 170, total rewards: 1825.994878.3, cost: 24678352.000000, total money: 10809.354863
# epoch: 180, total rewards: 1933.640443.3, cost: 25669770.000000, total money: 2330.380433
# epoch: 190, total rewards: 1830.469913.3, cost: 738614.125000, total money: 11830.469913
# epoch: 200, total rewards: 1312.225341.3, cost: 2372187.000000, total money: 10295.115356

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 0: buy 1 unit at price 768.700012, total balance 9231.299988
# day 1: buy 1 unit at price 762.130005, total balance 8469.169983
# day 2: buy 1 unit at price 762.020020, total balance 7707.149963
# day 3, sell 1 unit at price 782.520020, investment 1.797842 %, total balance 8489.669983,
# day 4, sell 1 unit at price 790.510010, investment 3.723775 %, total balance 9280.179993,
# day 5, sell 1 unit at price 785.309998, investment 3.056347 %, total balance 10065.489991,
# day 10: buy 1 unit at price 764.479980, total balance 9301.010011
# day 11: buy 1 unit at price 771.229980, total balance 8529.780031
# day 12, sell 1 unit at price 760.539978, investment -0.515383 %, total balance 9290.320009,
# day 13, sell 1 unit at price 769.200012, investment -0.263212 %, total balance 10059.520021,
# day 14: buy 1 unit at price 768.270020, total balance 9291.250001
# day 17, sell 1 unit at price 768.239990, investment -0.003909 %, total balance 10059.489991,
# day 19: buy 1 unit at price 758.039978, total balance 9301.450013
# day 21: buy 1 unit at price 750.500000, total balance 8550.950013
# day 22, sell 1 unit at price 762.520020, investment 0.591003 %, total balance 9313.470033,
# day 23, sell 1 unit at price 759.109985, investment 1.147233 %, total balance 10072.580018,
# day 24: buy 1 unit at price 771.190002, total balance 9301.390016
# day 27, sell 1 unit at price 789.270020, investment 2.344431 %, total balance 10090.660036,
# day 28: buy 1 unit at price 796.099976, total balance 9294.560060
# day 29, sell 1 unit at price 797.070007, investment 0.121848 %, total balance 10091.630067,
# day 35: buy 1 unit at price 791.260010, total balance 9300.370057
# day 37: buy 1 unit at price 791.549988, total balance 8508.820069
# day 39: buy 1 unit at price 782.789978, total balance 7726.030091
# day 40: buy 1 unit at price 771.820007, total balance 6954.210084
# day 41, sell 1 unit at price 786.140015, investment -0.647069 %, total balance 7740.350099,
# day 42: buy 1 unit at price 786.900024, total balance 6953.450075
# day 44: buy 1 unit at price 806.150024, total balance 6147.300051
# day 46, sell 1 unit at price 804.789978, investment 1.672666 %, total balance 6952.090029,
# day 47, sell 1 unit at price 807.909973, investment 3.209034 %, total balance 7760.000002,
# day 48, sell 1 unit at price 806.359985, investment 4.475134 %, total balance 8566.359987,
# day 50: buy 1 unit at price 804.609985, total balance 7761.750002
# day 51, sell 1 unit at price 806.070007, investment 2.436140 %, total balance 8567.820009,
# day 52: buy 1 unit at price 802.174988, total balance 7765.645021
# day 53: buy 1 unit at price 805.020020, total balance 6960.625001
# day 54, sell 1 unit at price 819.309998, investment 1.632447 %, total balance 7779.934999,
# day 57: buy 1 unit at price 832.150024, total balance 6947.784975
# day 58: buy 1 unit at price 823.309998, total balance 6124.474977
# day 59: buy 1 unit at price 802.320007, total balance 5322.154970
# day 60, sell 1 unit at price 796.789978, investment -0.971900 %, total balance 6118.944948,
# day 61, sell 1 unit at price 795.695007, investment -0.807801 %, total balance 6914.639955,
# day 63, sell 1 unit at price 801.489990, investment -0.438502 %, total balance 7716.129945,
# day 64, sell 1 unit at price 801.340027, investment -3.702457 %, total balance 8517.469972,
# day 65: buy 1 unit at price 806.969971, total balance 7710.500001
# day 66, sell 1 unit at price 808.380005, investment -1.813411 %, total balance 8518.880006,
# day 68: buy 1 unit at price 813.669983, total balance 7705.210023
# day 70, sell 1 unit at price 820.450012, investment 2.259697 %, total balance 8525.660035,
# day 71: buy 1 unit at price 818.979980, total balance 7706.680055
# day 72, sell 1 unit at price 824.159973, investment 2.130191 %, total balance 8530.840028,
# day 73, sell 1 unit at price 828.070007, investment 1.769762 %, total balance 9358.910035,
# day 74: buy 1 unit at price 831.659973, total balance 8527.250062
# day 75, sell 1 unit at price 830.760010, investment 1.438378 %, total balance 9358.010072,
# day 77: buy 1 unit at price 828.640015, total balance 8529.370057
# day 78: buy 1 unit at price 829.280029, total balance 7700.090028
# day 79: buy 1 unit at price 823.210022, total balance 6876.880006
# day 83: buy 1 unit at price 827.780029, total balance 6049.099977
# day 84: buy 1 unit at price 831.909973, total balance 5217.190004
# day 85, sell 1 unit at price 835.369995, investment 0.446098 %, total balance 6052.559999,
# day 86: buy 1 unit at price 838.679993, total balance 5213.880006
# day 87, sell 1 unit at price 843.250000, investment 1.763128 %, total balance 6057.130006,
# day 88: buy 1 unit at price 845.539978, total balance 5211.590028
# day 90, sell 1 unit at price 847.200012, investment 2.160909 %, total balance 6058.790040,
# day 91: buy 1 unit at price 848.780029, total balance 5210.010011
# day 92: buy 1 unit at price 852.119995, total balance 4357.890016
# day 93, sell 1 unit at price 848.400024, investment 3.059973 %, total balance 5206.290040,
# day 96, sell 1 unit at price 817.580017, investment -1.232213 %, total balance 6023.870057,
# day 97: buy 1 unit at price 814.429993, total balance 5209.440064
# day 98, sell 1 unit at price 819.510010, investment -1.490541 %, total balance 6028.950074,
# day 100, sell 1 unit at price 831.409973, investment -0.866841 %, total balance 6860.360047,
# day 101: buy 1 unit at price 831.500000, total balance 6028.860047
# day 103: buy 1 unit at price 838.549988, total balance 5190.310059
# day 104: buy 1 unit at price 834.570007, total balance 4355.740052
# day 105: buy 1 unit at price 831.409973, total balance 3524.330079
# day 106: buy 1 unit at price 827.880005, total balance 2696.450074
# day 108: buy 1 unit at price 824.729980, total balance 1871.720094
# day 109: buy 1 unit at price 823.349976, total balance 1048.370118
# day 111: buy 1 unit at price 823.559998, total balance 224.810120
# day 116, sell 1 unit at price 843.190002, investment -0.277926 %, total balance 1068.000122,
# day 117, sell 1 unit at price 862.760010, investment 1.647068 %, total balance 1930.760132,
# day 119, sell 1 unit at price 871.729980, investment 2.301317 %, total balance 2802.490112,
# day 121, sell 1 unit at price 905.960022, investment 11.238539 %, total balance 3708.450134,
# day 122: buy 1 unit at price 912.570007, total balance 2795.880127
# day 123, sell 1 unit at price 916.440002, investment 10.215274 %, total balance 3712.320129,
# day 124, sell 1 unit at price 927.039978, investment 10.552739 %, total balance 4639.360107,
# day 126, sell 1 unit at price 927.130005, investment 11.090741 %, total balance 5566.490112,
# day 127, sell 1 unit at price 934.299988, investment 12.375365 %, total balance 6500.790100,
# day 129, sell 1 unit at price 928.780029, investment 12.187760 %, total balance 7429.570129,
# day 130, sell 1 unit at price 930.599976, investment 12.836928 %, total balance 8360.170105,
# day 131, sell 1 unit at price 932.219971, investment 13.222809 %, total balance 9292.390076,
# day 134: buy 1 unit at price 919.619995, total balance 8372.770081
# day 136: buy 1 unit at price 934.010010, total balance 7438.760071
# day 138: buy 1 unit at price 948.820007, total balance 6489.940064
# day 140, sell 1 unit at price 969.539978, investment 17.725482 %, total balance 7459.480042,
# day 141, sell 1 unit at price 971.469971, investment 6.454295 %, total balance 8430.950013,
# day 142, sell 1 unit at price 975.880005, investment 6.117745 %, total balance 9406.830018,
# day 143: buy 1 unit at price 964.859985, total balance 8441.970033
# day 144, sell 1 unit at price 966.950012, investment 3.526729 %, total balance 9408.920045,
# day 145: buy 1 unit at price 975.599976, total balance 8433.320069
# day 146: buy 1 unit at price 983.679993, total balance 7449.640076
# day 148: buy 1 unit at price 980.940002, total balance 6468.700074
# day 149: buy 1 unit at price 983.409973, total balance 5485.290101
# day 150: buy 1 unit at price 949.830017, total balance 4535.460084
# day 151, sell 1 unit at price 942.900024, investment -0.623931 %, total balance 5478.360108,
# day 152, sell 1 unit at price 953.400024, investment -1.187733 %, total balance 6431.760132,
# day 154: buy 1 unit at price 942.309998, total balance 5489.450134
# day 155, sell 1 unit at price 939.780029, investment -3.671581 %, total balance 6429.230163,
# day 156, sell 1 unit at price 957.369995, investment -2.674650 %, total balance 7386.600158,
# day 157: buy 1 unit at price 950.630005, total balance 6435.970153
# day 159: buy 1 unit at price 957.090027, total balance 5478.880126
# day 161, sell 1 unit at price 952.270020, investment -2.922705 %, total balance 6431.150146,
# day 163, sell 1 unit at price 940.489990, investment -4.364404 %, total balance 7371.640136,
# day 164: buy 1 unit at price 917.789978, total balance 6453.850158
# day 165, sell 1 unit at price 908.729980, investment -4.327094 %, total balance 7362.580138,
# day 168, sell 1 unit at price 906.690002, investment -3.780072 %, total balance 8269.270140,
# day 169: buy 1 unit at price 918.590027, total balance 7350.680113
# day 170, sell 1 unit at price 928.799988, investment -2.296374 %, total balance 8279.480101,
# day 172, sell 1 unit at price 943.830017, investment -1.385451 %, total balance 9223.310118,
# day 174, sell 1 unit at price 955.989990, investment 4.162174 %, total balance 10179.300108,
# day 175: buy 1 unit at price 953.419983, total balance 9225.880125
# day 178: buy 1 unit at price 968.150024, total balance 8257.730101
# day 179, sell 1 unit at price 972.919983, investment 5.914494 %, total balance 9230.650084,
# day 180, sell 1 unit at price 980.340027, investment 2.823524 %, total balance 10210.990111,
# day 182: buy 1 unit at price 947.799988, total balance 9263.190123
# day 183, sell 1 unit at price 934.090027, investment -3.518049 %, total balance 10197.280150,
# day 185, sell 1 unit at price 930.500000, investment -1.825278 %, total balance 11127.780150,
# day 186: buy 1 unit at price 930.830017, total balance 10196.950133
# day 187: buy 1 unit at price 930.390015, total balance 9266.560118
# day 188: buy 1 unit at price 923.650024, total balance 8342.910094
# day 189: buy 1 unit at price 927.960022, total balance 7414.950072
# day 190: buy 1 unit at price 929.359985, total balance 6485.590087
# day 193: buy 1 unit at price 907.239990, total balance 5578.350097
# day 194: buy 1 unit at price 914.390015, total balance 4663.960082
# day 195, sell 1 unit at price 922.669983, investment -0.876641 %, total balance 5586.630065,
# day 199: buy 1 unit at price 910.669983, total balance 4675.960082
# day 200: buy 1 unit at price 906.659973, total balance 3769.300109
# day 201: buy 1 unit at price 924.690002, total balance 2844.610107
# day 203: buy 1 unit at price 921.280029, total balance 1923.330078
# day 204: buy 1 unit at price 915.890015, total balance 1007.440063
# day 205: buy 1 unit at price 913.809998, total balance 93.630065
# day 206, sell 1 unit at price 921.289978, investment -0.978088 %, total balance 1014.920043,
# day 207, sell 1 unit at price 929.570007, investment 0.640934 %, total balance 1944.490050,
# day 209: buy 1 unit at price 937.340027, total balance 1007.150023
# day 212, sell 1 unit at price 935.950012, investment 0.861027 %, total balance 1943.100035,
# day 213: buy 1 unit at price 926.500000, total balance 1016.600035
# day 214, sell 1 unit at price 929.080017, investment -0.030125 %, total balance 1945.680052,
# day 215: buy 1 unit at price 932.070007, total balance 1013.610045
# day 217, sell 1 unit at price 925.109985, investment 1.969710 %, total balance 1938.720030,
# day 218: buy 1 unit at price 920.289978, total balance 1018.430052
# day 220, sell 1 unit at price 921.809998, investment 0.811468 %, total balance 1940.240050,
# day 221, sell 1 unit at price 931.580017, investment 2.296115 %, total balance 2871.820067,
# day 223, sell 1 unit at price 928.530029, investment 2.412156 %, total balance 3800.350096,
# day 224, sell 1 unit at price 920.969971, investment -0.402300 %, total balance 4721.320067,
# day 225, sell 1 unit at price 924.859985, investment 0.388585 %, total balance 5646.180052,
# day 228: buy 1 unit at price 959.109985, total balance 4687.070067
# day 230, sell 1 unit at price 957.789978, investment 4.574781 %, total balance 5644.860045,
# day 231: buy 1 unit at price 951.679993, total balance 4693.180052
# day 232: buy 1 unit at price 969.960022, total balance 3723.220030
# day 233, sell 1 unit at price 978.890015, investment 7.121832 %, total balance 4702.110045,
# day 234, sell 1 unit at price 977.000000, investment 4.231119 %, total balance 5679.110045,
# day 235: buy 1 unit at price 972.599976, total balance 4706.510069
# day 236, sell 1 unit at price 989.250000, investment 6.772801 %, total balance 5695.760069,
# day 237, sell 1 unit at price 987.830017, investment 5.982384 %, total balance 6683.590086,
# day 238: buy 1 unit at price 989.679993, total balance 5693.910093
# day 239, sell 1 unit at price 992.000000, investment 7.792112 %, total balance 6685.910093,
# day 240, sell 1 unit at price 992.179993, investment 3.447989 %, total balance 7678.090086,
# day 241: buy 1 unit at price 992.809998, total balance 6685.280088
# day 242: buy 1 unit at price 984.450012, total balance 5700.830076
# day 243, sell 1 unit at price 988.200012, investment 3.837426 %, total balance 6689.030088,
# day 244: buy 1 unit at price 968.450012, total balance 5720.580076
# day 245, sell 1 unit at price 970.539978, investment 0.059792 %, total balance 6691.120054,
# day 250, sell 1 unit at price 1016.640015, investment 4.528073 %, total balance 7707.760069,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
