# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.neighbors import NearestNeighbors
import seaborn as sns
tf.compat.v1.disable_eager_execution()
sns.set()

# %%
df = pd.read_csv('/Users/gkumargaur/workspace/python/gitprojects/Stock-Prediction-Models/dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2020-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2020-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2020-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2020-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2020-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1

novelty_search_threshold = 6
novelty_log_maxlen = 1000
backlog_maxsize = 500
novelty_log_add_amount = 3

# %%
class neuralnetwork:
    def __init__(self, id_, hidden_size = 128):
        self.W1 = np.random.randn(window_size, hidden_size) / np.sqrt(window_size)
        self.W2 = np.random.randn(hidden_size, 3) / np.sqrt(hidden_size)
        self.fitness = 0
        self.last_features = None
        self.id = id_

def relu(X):
    return np.maximum(X, 0)

def softmax(X):
    e_x = np.exp(X - np.max(X, axis=-1, keepdims=True))
    return e_x / np.sum(e_x, axis=-1, keepdims=True)

def feed_forward(X, nets):
    a1 = np.dot(X, nets.W1)
    z1 = relu(a1)
    a2 = np.dot(z1, nets.W2)
    return softmax(a2)

# %%
class NeuroEvolution:
    def __init__(self, population_size, mutation_rate, model_generator,
                state_size, window_size, trend, skip, initial_money):
        self.population_size = population_size
        self.mutation_rate = mutation_rate
        self.model_generator = model_generator
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.initial_money = initial_money
        self.generation_backlog = []
        self.novel_backlog = []
        self.novel_pop = []

    def _initialize_population(self):
        self.population = []
        for i in range(self.population_size):
            self.population.append(self.model_generator(i))

    def _memorize(self, q, i, limit):
        q.append(i)
        if len(q) > limit:
            q.pop()

    def mutate(self, individual, scale=1.0):
        mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=individual.W1.shape)
        individual.W1 += np.random.normal(loc=0, scale=scale, size=individual.W1.shape) * mutation_mask
        mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=individual.W2.shape)
        individual.W2 += np.random.normal(loc=0, scale=scale, size=individual.W2.shape) * mutation_mask
        return individual

    def inherit_weights(self, parent, child):
        child.W1 = parent.W1.copy()
        child.W2 = parent.W2.copy()
        return child

    def crossover(self, parent1, parent2):
        child1 = self.model_generator((parent1.id+1)*10)
        child1 = self.inherit_weights(parent1, child1)
        child2 = self.model_generator((parent2.id+1)*10)
        child2 = self.inherit_weights(parent2, child2)
        # first W
        n_neurons = child1.W1.shape[1]
        cutoff = np.random.randint(0, n_neurons)
        child1.W1[:, cutoff:] = parent2.W1[:, cutoff:].copy()
        child2.W1[:, cutoff:] = parent1.W1[:, cutoff:].copy()
        # second W
        n_neurons = child1.W2.shape[1]
        cutoff = np.random.randint(0, n_neurons)
        child1.W2[:, cutoff:] = parent2.W2[:, cutoff:].copy()
        child2.W2[:, cutoff:] = parent1.W2[:, cutoff:].copy()
        return child1, child2

    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def act(self, p, state):
        logits = feed_forward(state, p)
        return np.argmax(logits, 1)[0]

    def buy(self, individual):
        initial_money = self.initial_money
        starting_money = initial_money
        state = self.get_state(0)
        inventory = []
        states_sell = []
        states_buy = []

        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(individual, state)
            next_state = self.get_state(t + 1)

            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))

            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((self.trend[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, self.trend[t], invest, initial_money)
                )
            state = next_state

        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest

    def calculate_fitness(self):
        for i in range(self.population_size):
            initial_money = self.initial_money
            starting_money = initial_money
            state = self.get_state(0)
            inventory = []

            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(self.population[i], state)
                next_state = self.get_state(t + 1)

                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]

                elif action == 2 and len(inventory):
                    bought_price = inventory.pop(0)
                    starting_money += self.trend[t]

                state = next_state
            invest = ((starting_money - initial_money) / initial_money) * 100
            self.population[i].fitness = invest
            self.population[i].last_features = self.population[i].W2.flatten()

    def evaluate(self, individual, backlog, pop, k = 4):
        score = 0
        if len(backlog):
            x = np.array(backlog)
            nn = NearestNeighbors(n_neighbors = k, metric = 'euclidean').fit(np.array(backlog))
            d, _ = nn.kneighbors([individual])
            score += np.mean(d)

        if len(pop):
            nn = NearestNeighbors(n_neighbors = k, metric = 'euclidean').fit(np.array(pop))
            d, _ = nn.kneighbors([individual])
            score += np.mean(d)

        return score

    def evolve(self, generations=20, checkpoint= 5):
        self._initialize_population()
        n_winners = int(self.population_size * 0.4)
        n_parents = self.population_size - n_winners
        for epoch in range(generations):
            self.calculate_fitness()
            scores = [self.evaluate(p.last_features, self.novel_backlog, self.novel_pop) for p in self.population]
            sort_fitness = np.argsort(scores)[::-1]
            self.population = [self.population[i] for i in sort_fitness]
            fittest_individual = self.population[0]
            if (epoch+1) % checkpoint == 0:
                print('epoch %d, fittest individual %d with accuracy %f'%(epoch+1, sort_fitness[0],
                                                                          fittest_individual.fitness))
            next_population = [self.population[i] for i in range(n_winners)]
            total_fitness = np.sum([np.abs(i.fitness) for i in self.population])
            parent_probabilities = [np.abs(i.fitness / total_fitness) for i in self.population]
            parents = np.random.choice(self.population, size=n_parents, p=parent_probabilities, replace=False)

            for p in next_population:
                if p.last_features is not None:
                    self._memorize(self.novel_pop, p.last_features, backlog_maxsize)
                    if np.random.randint(0,10) < novelty_search_threshold:
                        self._memorize(self.novel_backlog, p.last_features, novelty_log_maxlen)

            for i in np.arange(0, len(parents), 2):
                child1, child2 = self.crossover(parents[i], parents[i+1])
                next_population += [self.mutate(child1), self.mutate(child2)]
            self.population = next_population

            if np.random.randint(0,10) < novelty_search_threshold:
                pop_sorted = sorted(self.population, key=lambda p: p.fitness, reverse=True)
                self.generation_backlog.append(pop_sorted[0])
                print('novel add fittest, score: %f, backlog size: %d'%(pop_sorted[0].fitness,
                                                                        len(self.generation_backlog)))
                generation_backlog_temp = self.generation_backlog
                if len(self.generation_backlog) > backlog_maxsize:
                    generation_backlog_temp = random.sample(generation_backlog, backlog_maxsize)
                for p in generation_backlog_temp:
                    if p.last_features is not None:
                        self._memorize(self.novel_backlog, p.last_features, novelty_log_maxlen)

        return fittest_individual

# %%
population_size = 100
generations = 100
mutation_rate = 0.1
neural_evolve = NeuroEvolution(population_size, mutation_rate, neuralnetwork,
                              window_size, window_size, close, skip, initial_money)

# %%
fittest_nets = neural_evolve.evolve(100)
# Out:
# novel add fittest, score: 7.590248, backlog size: 1
# novel add fittest, score: 6.341250, backlog size: 2
# novel add fittest, score: 9.461903, backlog size: 3
# epoch 5, fittest individual 57 with accuracy -94.055900
# novel add fittest, score: 0.806001, backlog size: 4
# novel add fittest, score: 3.637850, backlog size: 5
# novel add fittest, score: 3.626650, backlog size: 6
# novel add fittest, score: 8.925100, backlog size: 7
# epoch 10, fittest individual 72 with accuracy -92.143201
# novel add fittest, score: 0.000000, backlog size: 8
# novel add fittest, score: 15.068353, backlog size: 9
# novel add fittest, score: 4.086649, backlog size: 10
# epoch 15, fittest individual 92 with accuracy -99.276600
# novel add fittest, score: 0.000000, backlog size: 11
# novel add fittest, score: 4.628502, backlog size: 12
# novel add fittest, score: 9.130799, backlog size: 13
# novel add fittest, score: 0.000000, backlog size: 14
# epoch 20, fittest individual 66 with accuracy -97.851400
# novel add fittest, score: 0.586303, backlog size: 15
# novel add fittest, score: 6.794849, backlog size: 16
# novel add fittest, score: 0.000000, backlog size: 17
# novel add fittest, score: 0.000000, backlog size: 18
# epoch 25, fittest individual 51 with accuracy -98.661499
# novel add fittest, score: 0.000000, backlog size: 19
# novel add fittest, score: 0.000000, backlog size: 20
# epoch 30, fittest individual 41 with accuracy -92.784950
# novel add fittest, score: 0.000000, backlog size: 21
# novel add fittest, score: 0.816000, backlog size: 22
# epoch 35, fittest individual 86 with accuracy -99.251201
# novel add fittest, score: 0.000000, backlog size: 23
# novel add fittest, score: 0.000000, backlog size: 24
# novel add fittest, score: 0.000000, backlog size: 25
# novel add fittest, score: 0.000000, backlog size: 26
# epoch 40, fittest individual 0 with accuracy -86.706653
# novel add fittest, score: 0.000000, backlog size: 27
# novel add fittest, score: 0.000000, backlog size: 28
# novel add fittest, score: 0.000000, backlog size: 29
# novel add fittest, score: 0.000000, backlog size: 30
# epoch 45, fittest individual 92 with accuracy -96.668749
# novel add fittest, score: 0.000000, backlog size: 31
# novel add fittest, score: 0.000000, backlog size: 32
# novel add fittest, score: 0.000000, backlog size: 33
# novel add fittest, score: 0.000000, backlog size: 34
# epoch 50, fittest individual 53 with accuracy -91.598748
# novel add fittest, score: 0.000000, backlog size: 35
# epoch 55, fittest individual 95 with accuracy -99.669100
# novel add fittest, score: 0.000000, backlog size: 36
# novel add fittest, score: 0.000000, backlog size: 37
# novel add fittest, score: 0.000000, backlog size: 38
# epoch 60, fittest individual 74 with accuracy -99.397399
# novel add fittest, score: 0.000000, backlog size: 39
# novel add fittest, score: 0.000000, backlog size: 40
# novel add fittest, score: 0.000000, backlog size: 41
# epoch 65, fittest individual 74 with accuracy -99.956551
# novel add fittest, score: 0.000000, backlog size: 42
# novel add fittest, score: 0.000000, backlog size: 43
# epoch 70, fittest individual 97 with accuracy -99.009401
# novel add fittest, score: 0.000000, backlog size: 44
# novel add fittest, score: 0.000000, backlog size: 45
# novel add fittest, score: 0.000000, backlog size: 46
# novel add fittest, score: 0.000000, backlog size: 47
# epoch 75, fittest individual 54 with accuracy -99.451650
# novel add fittest, score: 0.000000, backlog size: 48
# epoch 80, fittest individual 70 with accuracy -99.901200
# novel add fittest, score: 0.000000, backlog size: 49
# novel add fittest, score: 0.000000, backlog size: 50
# novel add fittest, score: 0.000000, backlog size: 51
# epoch 85, fittest individual 66 with accuracy -99.417799
# novel add fittest, score: 0.000000, backlog size: 52
# novel add fittest, score: 0.000000, backlog size: 53
# epoch 90, fittest individual 40 with accuracy -99.591649
# novel add fittest, score: 0.000000, backlog size: 54
# novel add fittest, score: 0.000000, backlog size: 55
# novel add fittest, score: 0.000000, backlog size: 56
# novel add fittest, score: 0.000000, backlog size: 57
# epoch 95, fittest individual 76 with accuracy -81.584901
# novel add fittest, score: 0.000000, backlog size: 58
# novel add fittest, score: 0.000000, backlog size: 59
# epoch 100, fittest individual 72 with accuracy -82.059048

# %%
states_buy, states_sell, total_gains, invest = neural_evolve.buy(fittest_nets)
# Out:
# day 3: buy 1 unit at price 782.520020, total balance 9217.479980
# day 4: buy 1 unit at price 790.510010, total balance 8426.969970
# day 5: buy 1 unit at price 785.309998, total balance 7641.659972
# day 8, sell 1 unit at price 736.080017, investment -5.934673 %, total balance 8377.739989,
# day 9: buy 1 unit at price 758.489990, total balance 7619.249999
# day 11: buy 1 unit at price 771.229980, total balance 6848.020019
# day 12: buy 1 unit at price 760.539978, total balance 6087.480041
# day 14: buy 1 unit at price 768.270020, total balance 5319.210021
# day 15: buy 1 unit at price 760.989990, total balance 4558.220031
# day 18: buy 1 unit at price 770.840027, total balance 3787.380004
# day 19: buy 1 unit at price 758.039978, total balance 3029.340026
# day 20: buy 1 unit at price 747.919983, total balance 2281.420043
# day 22: buy 1 unit at price 762.520020, total balance 1518.900023
# day 25: buy 1 unit at price 776.419983, total balance 742.480040
# day 26: buy 1 unit at price 789.289978, total balance -46.809938
# day 28: buy 1 unit at price 796.099976, total balance -842.909914
# day 29: buy 1 unit at price 797.070007, total balance -1639.979921
# day 31: buy 1 unit at price 790.799988, total balance -2430.779909
# day 33: buy 1 unit at price 796.419983, total balance -3227.199892
# day 34: buy 1 unit at price 794.559998, total balance -4021.759890
# day 35: buy 1 unit at price 791.260010, total balance -4813.019900
# day 37: buy 1 unit at price 791.549988, total balance -5604.569888
# day 38: buy 1 unit at price 785.049988, total balance -6389.619876
# day 39: buy 1 unit at price 782.789978, total balance -7172.409854
# day 41: buy 1 unit at price 786.140015, total balance -7958.549869
# day 42: buy 1 unit at price 786.900024, total balance -8745.449893
# day 43: buy 1 unit at price 794.020020, total balance -9539.469913
# day 44: buy 1 unit at price 806.150024, total balance -10345.619937
# day 45, sell 1 unit at price 806.650024, investment 2.041722 %, total balance -9538.969913,
# day 48: buy 1 unit at price 806.359985, total balance -10345.329898
# day 49: buy 1 unit at price 807.880005, total balance -11153.209903
# day 50, sell 1 unit at price 804.609985, investment 2.457627 %, total balance -10348.599918,
# day 52: buy 1 unit at price 802.174988, total balance -11150.774906
# day 53: buy 1 unit at price 805.020020, total balance -11955.794926
# day 54: buy 1 unit at price 819.309998, total balance -12775.104924
# day 56: buy 1 unit at price 835.669983, total balance -13610.774907
# day 57, sell 1 unit at price 832.150024, investment 9.711405 %, total balance -12778.624883,
# day 59: buy 1 unit at price 802.320007, total balance -13580.944890
# day 60: buy 1 unit at price 796.789978, total balance -14377.734868
# day 63: buy 1 unit at price 801.489990, total balance -15179.224858
# day 66: buy 1 unit at price 808.380005, total balance -15987.604863
# day 70: buy 1 unit at price 820.450012, total balance -16808.054875
# day 71: buy 1 unit at price 818.979980, total balance -17627.034855
# day 72: buy 1 unit at price 824.159973, total balance -18451.194828
# day 73: buy 1 unit at price 828.070007, total balance -19279.264835
# day 74: buy 1 unit at price 831.659973, total balance -20110.924808
# day 80: buy 1 unit at price 835.239990, total balance -20946.164798
# day 81: buy 1 unit at price 830.630005, total balance -21776.794803
# day 82: buy 1 unit at price 829.080017, total balance -22605.874820
# day 83: buy 1 unit at price 827.780029, total balance -23433.654849
# day 84: buy 1 unit at price 831.909973, total balance -24265.564822
# day 85: buy 1 unit at price 835.369995, total balance -25100.934817
# day 86: buy 1 unit at price 838.679993, total balance -25939.614810
# day 87: buy 1 unit at price 843.250000, total balance -26782.864810
# day 88: buy 1 unit at price 845.539978, total balance -27628.404788
# day 89: buy 1 unit at price 845.619995, total balance -28474.024783
# day 90: buy 1 unit at price 847.200012, total balance -29321.224795
# day 91: buy 1 unit at price 848.780029, total balance -30170.004824
# day 92: buy 1 unit at price 852.119995, total balance -31022.124819
# day 93, sell 1 unit at price 848.400024, investment 10.006100 %, total balance -30173.724795,
# day 96, sell 1 unit at price 817.580017, investment 7.499940 %, total balance -29356.144778,
# day 100: buy 1 unit at price 831.409973, total balance -30187.554751
# day 104: buy 1 unit at price 834.570007, total balance -31022.124758
# day 107: buy 1 unit at price 824.669983, total balance -31846.794741
# day 108: buy 1 unit at price 824.729980, total balance -32671.524721
# day 110: buy 1 unit at price 824.320007, total balance -33495.844728
# day 112: buy 1 unit at price 837.169983, total balance -34333.014711
# day 113, sell 1 unit at price 836.820007, investment 8.922642 %, total balance -33496.194704,
# day 115: buy 1 unit at price 841.650024, total balance -34337.844728
# day 116: buy 1 unit at price 843.190002, total balance -35181.034730
# day 117: buy 1 unit at price 862.760010, total balance -36043.794740
# day 118: buy 1 unit at price 872.299988, total balance -36916.094728
# day 119: buy 1 unit at price 871.729980, total balance -37787.824708
# day 121: buy 1 unit at price 905.960022, total balance -38693.784730
# day 122: buy 1 unit at price 912.570007, total balance -39606.354737
# day 123: buy 1 unit at price 916.440002, total balance -40522.794739
# day 124: buy 1 unit at price 927.039978, total balance -41449.834717
# day 125: buy 1 unit at price 931.659973, total balance -42381.494690
# day 126: buy 1 unit at price 927.130005, total balance -43308.624695
# day 127: buy 1 unit at price 934.299988, total balance -44242.924683
# day 128: buy 1 unit at price 932.169983, total balance -45175.094666
# day 129: buy 1 unit at price 928.780029, total balance -46103.874695
# day 130: buy 1 unit at price 930.599976, total balance -47034.474671
# day 133: buy 1 unit at price 943.000000, total balance -47977.474671
# day 134: buy 1 unit at price 919.619995, total balance -48897.094666
# day 136: buy 1 unit at price 934.010010, total balance -49831.104676
# day 137: buy 1 unit at price 941.859985, total balance -50772.964661
# day 139, sell 1 unit at price 954.960022, investment 25.489170 %, total balance -49818.004639,
# day 140: buy 1 unit at price 969.539978, total balance -50787.544617
# day 141, sell 1 unit at price 971.469971, investment 26.027442 %, total balance -49816.074646,
# day 143: buy 1 unit at price 964.859985, total balance -50780.934631
# day 144: buy 1 unit at price 966.950012, total balance -51747.884643
# day 145: buy 1 unit at price 975.599976, total balance -52723.484619
# day 147: buy 1 unit at price 976.570007, total balance -53700.054626
# day 148: buy 1 unit at price 980.940002, total balance -54680.994628
# day 155: buy 1 unit at price 939.780029, total balance -55620.774657
# day 157, sell 1 unit at price 950.630005, investment 25.406315 %, total balance -54670.144652,
# day 158: buy 1 unit at price 959.450012, total balance -55629.594664
# day 161: buy 1 unit at price 952.270020, total balance -56581.864684
# day 164, sell 1 unit at price 917.789978, investment 22.712322 %, total balance -55664.074706,
# day 165: buy 1 unit at price 908.729980, total balance -56572.804686
# day 168: buy 1 unit at price 906.690002, total balance -57479.494688
# day 171: buy 1 unit at price 930.090027, total balance -58409.584715
# day 172: buy 1 unit at price 943.830017, total balance -59353.414732
# day 175: buy 1 unit at price 953.419983, total balance -60306.834715
# day 176: buy 1 unit at price 965.400024, total balance -61272.234739
# day 178: buy 1 unit at price 968.150024, total balance -62240.384763
# day 179: buy 1 unit at price 972.919983, total balance -63213.304746
# day 180, sell 1 unit at price 980.340027, investment 28.565808 %, total balance -62232.964719,
# day 182: buy 1 unit at price 947.799988, total balance -63180.764707
# day 184: buy 1 unit at price 941.530029, total balance -64122.294736
# day 185: buy 1 unit at price 930.500000, total balance -65052.794736
# day 186: buy 1 unit at price 930.830017, total balance -65983.624753
# day 187: buy 1 unit at price 930.390015, total balance -66914.014768
# day 189: buy 1 unit at price 927.960022, total balance -67841.974790
# day 191: buy 1 unit at price 926.789978, total balance -68768.764768
# day 192: buy 1 unit at price 922.900024, total balance -69691.664792
# day 195: buy 1 unit at price 922.669983, total balance -70614.334775
# day 196: buy 1 unit at price 922.219971, total balance -71536.554746
# day 199: buy 1 unit at price 910.669983, total balance -72447.224729
# day 200, sell 1 unit at price 906.659973, investment 16.774425 %, total balance -71540.564756,
# day 202: buy 1 unit at price 927.000000, total balance -72467.564756
# day 203: buy 1 unit at price 921.280029, total balance -73388.844785
# day 204: buy 1 unit at price 915.890015, total balance -74304.734800
# day 206: buy 1 unit at price 921.289978, total balance -75226.024778
# day 207: buy 1 unit at price 929.570007, total balance -76155.594785
# day 210: buy 1 unit at price 928.450012, total balance -77084.044797
# day 212: buy 1 unit at price 935.950012, total balance -78019.994809
# day 213: buy 1 unit at price 926.500000, total balance -78946.494809
# day 214: buy 1 unit at price 929.080017, total balance -79875.574826
# day 216: buy 1 unit at price 935.090027, total balance -80810.664853
# day 217: buy 1 unit at price 925.109985, total balance -81735.774838
# day 218: buy 1 unit at price 920.289978, total balance -82656.064816
# day 220: buy 1 unit at price 921.809998, total balance -83577.874814
# day 221: buy 1 unit at price 931.580017, total balance -84509.454831
# day 223: buy 1 unit at price 928.530029, total balance -85437.984860
# day 224: buy 1 unit at price 920.969971, total balance -86358.954831
# day 225: buy 1 unit at price 924.859985, total balance -87283.814816
# day 227: buy 1 unit at price 949.500000, total balance -88233.314816
# day 228: buy 1 unit at price 959.109985, total balance -89192.424801
# day 230: buy 1 unit at price 957.789978, total balance -90150.214779
# day 231: buy 1 unit at price 951.679993, total balance -91101.894772
# day 232: buy 1 unit at price 969.960022, total balance -92071.854794
# day 233: buy 1 unit at price 978.890015, total balance -93050.744809
# day 234, sell 1 unit at price 977.000000, investment 23.782137 %, total balance -92073.744809,
# day 235: buy 1 unit at price 972.599976, total balance -93046.344785
# day 236: buy 1 unit at price 989.250000, total balance -94035.594785
# day 237: buy 1 unit at price 987.830017, total balance -95023.424802
# day 238: buy 1 unit at price 989.679993, total balance -96013.104795
# day 241: buy 1 unit at price 992.809998, total balance -97005.914793
# day 242: buy 1 unit at price 984.450012, total balance -97990.364805
# day 243: buy 1 unit at price 988.200012, total balance -98978.564817
# day 244, sell 1 unit at price 968.450012, investment 21.649295 %, total balance -98010.114805,
# day 245: buy 1 unit at price 970.539978, total balance -98980.654783
# day 248: buy 1 unit at price 1019.270020, total balance -99999.924803
# day 249, sell 1 unit at price 1017.109985, investment 27.606104 %, total balance -98982.814818,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
