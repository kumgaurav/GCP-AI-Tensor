# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
tf.compat.v1.disable_eager_execution()
sns.set()

# %%
df = pd.read_csv('/Users/gkumargaur/workspace/python/gitprojects/Stock-Prediction-Models/dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2020-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2020-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2020-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2020-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2020-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
from collections import deque
import random

class Model:
    def __init__(self, input_size, output_size, layer_size, learning_rate):
        self.X = tf.compat.v1.placeholder(tf.float32, (None, input_size))
        self.Y = tf.compat.v1.placeholder(tf.float32, (None, output_size))
        feed_forward = tf.compat.v1.layers.dense(self.X, layer_size, activation = tf.nn.relu)
        self.logits = tf.compat.v1.layers.dense(feed_forward, output_size)
        self.cost = tf.reduce_sum(input_tensor=tf.square(self.Y - self.logits))
        self.optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)

class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 500
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300

    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.compat.v1.reset_default_graph()
        self.model = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.model_negative = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.sess = tf.compat.v1.InteractiveSession()
        self.sess.run(tf.compat.v1.global_variables_initializer())
        self.trainable = tf.compat.v1.trainable_variables()

    def _assign(self):
        for i in range(len(self.trainable)//2):
            assign_op = self.trainable[i+len(self.trainable)//2].assign(self.trainable[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, done):
        self.MEMORIES.append((state, action, reward, new_state, done))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.predict(states)
        Q_new = self.predict(new_states)
        Q_new_negative = self.sess.run(self.model_negative.logits, feed_dict={self.model_negative.X:new_states})
        replay_size = len(replay)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, done_r = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not done_r:
                target[action_r] += self.GAMMA * Q_new_negative[i, np.argmax(Q_new[i])]
            X[i] = state_r
            Y[i] = target
        return X, Y

    def predict(self, inputs):
        return self.sess.run(self.model.logits, feed_dict={self.model.X:inputs})

    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)

    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)

    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)

            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))

            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )

            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest


    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign()

                action = self._select_action(state)
                next_state = self.get_state(t + 1)

                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]

                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]

                invest = ((starting_money - initial_money) / initial_money)

                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                state = next_state
                X, Y = self._construct_memories(replay)

                cost, _ = self.sess.run([self.model.cost, self.model.optimizer],
                                        feed_dict={self.model.X: X, self.model.Y:Y})
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size,
              window_size = window_size,
              trend = close,
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# /Users/gkumargaur/opt/miniconda3/envs/tensorflow/lib/python3.8/site-packages/tensorflow/python/keras/legacy_tf_layers/core.py:171: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   warnings.warn('`tf.layers.dense` is deprecated and '
# /Users/gkumargaur/opt/miniconda3/envs/tensorflow/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1692: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# epoch: 10, total rewards: 580.895211.3, cost: 1.100437, total money: 10580.895211
# epoch: 20, total rewards: 1298.760316.3, cost: 0.608978, total money: 3484.910339
# epoch: 30, total rewards: 532.404911.3, cost: 0.452856, total money: 6576.594913
# epoch: 40, total rewards: 1141.099858.3, cost: 1.235304, total money: 10167.769841
# epoch: 50, total rewards: 1351.234796.3, cost: 1.356913, total money: 3568.374809
# epoch: 60, total rewards: 1770.230165.3, cost: 0.954134, total money: 10753.120180
# epoch: 70, total rewards: 1308.294859.3, cost: 0.283911, total money: 5394.524839
# epoch: 80, total rewards: 496.329895.3, cost: 0.905112, total money: 4525.389892
# epoch: 90, total rewards: 533.039430.3, cost: 0.704323, total money: 8496.659425
# epoch: 100, total rewards: -78.969847.3, cost: 0.896427, total money: 9921.030153
# epoch: 110, total rewards: 107.355040.3, cost: 0.351973, total money: 10107.355040
# epoch: 120, total rewards: 467.794865.3, cost: 0.682102, total money: 6472.784855
# epoch: 130, total rewards: 479.339902.3, cost: 0.843950, total money: 825.889951
# epoch: 140, total rewards: 327.325434.3, cost: 0.331306, total money: 10327.325434
# epoch: 150, total rewards: 1238.579714.3, cost: 0.991698, total money: 11238.579714
# epoch: 160, total rewards: 587.639897.3, cost: 1.546758, total money: 10587.639897
# epoch: 170, total rewards: 1045.285156.3, cost: 1.936721, total money: 9053.455138
# epoch: 180, total rewards: 85.614867.3, cost: 0.209138, total money: 10085.614867
# epoch: 190, total rewards: 112.149845.3, cost: 0.038245, total money: 10112.149845
# epoch: 200, total rewards: 69.789975.3, cost: 0.038704, total money: 10069.789975

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 5: buy 1 unit at price 785.309998, total balance 9214.690002
# day 6, sell 1 unit at price 762.559998, investment -2.896945 %, total balance 9977.250000,
# day 12: buy 1 unit at price 760.539978, total balance 9216.710022
# day 14, sell 1 unit at price 768.270020, investment 1.016389 %, total balance 9984.980042,
# day 18: buy 1 unit at price 770.840027, total balance 9214.140015
# day 21, sell 1 unit at price 750.500000, investment -2.638683 %, total balance 9964.640015,
# day 25: buy 1 unit at price 776.419983, total balance 9188.220032
# day 27, sell 1 unit at price 789.270020, investment 1.655037 %, total balance 9977.490052,
# day 28: buy 1 unit at price 796.099976, total balance 9181.390076
# day 29, sell 1 unit at price 797.070007, investment 0.121848 %, total balance 9978.460083,
# day 33: buy 1 unit at price 796.419983, total balance 9182.040100
# day 34, sell 1 unit at price 794.559998, investment -0.233543 %, total balance 9976.600098,
# day 35: buy 1 unit at price 791.260010, total balance 9185.340088
# day 36, sell 1 unit at price 789.909973, investment -0.170619 %, total balance 9975.250061,
# day 46: buy 1 unit at price 804.789978, total balance 9170.460083
# day 47, sell 1 unit at price 807.909973, investment 0.387678 %, total balance 9978.370056,
# day 48: buy 1 unit at price 806.359985, total balance 9172.010071
# day 49, sell 1 unit at price 807.880005, investment 0.188504 %, total balance 9979.890076,
# day 50: buy 1 unit at price 804.609985, total balance 9175.280091
# day 52: buy 1 unit at price 802.174988, total balance 8373.105103
# day 54, sell 1 unit at price 819.309998, investment 1.826974 %, total balance 9192.415101,
# day 55, sell 1 unit at price 823.869995, investment 2.704523 %, total balance 10016.285096,
# day 60: buy 1 unit at price 796.789978, total balance 9219.495118
# day 61, sell 1 unit at price 795.695007, investment -0.137423 %, total balance 10015.190125,
# day 62: buy 1 unit at price 798.530029, total balance 9216.660096
# day 65, sell 1 unit at price 806.969971, investment 1.056935 %, total balance 10023.630067,
# day 68: buy 1 unit at price 813.669983, total balance 9209.960084
# day 69, sell 1 unit at price 819.239990, investment 0.684554 %, total balance 10029.200074,
# day 74: buy 1 unit at price 831.659973, total balance 9197.540101
# day 75, sell 1 unit at price 830.760010, investment -0.108213 %, total balance 10028.300111,
# day 76: buy 1 unit at price 831.330017, total balance 9196.970094
# day 77, sell 1 unit at price 828.640015, investment -0.323578 %, total balance 10025.610109,
# day 80: buy 1 unit at price 835.239990, total balance 9190.370119
# day 81, sell 1 unit at price 830.630005, investment -0.551935 %, total balance 10021.000124,
# day 82: buy 1 unit at price 829.080017, total balance 9191.920107
# day 83, sell 1 unit at price 827.780029, investment -0.156799 %, total balance 10019.700136,
# day 89: buy 1 unit at price 845.619995, total balance 9174.080141
# day 90, sell 1 unit at price 847.200012, investment 0.186847 %, total balance 10021.280153,
# day 95: buy 1 unit at price 829.590027, total balance 9191.690126
# day 97: buy 1 unit at price 814.429993, total balance 8377.260133
# day 98, sell 1 unit at price 819.510010, investment -1.215060 %, total balance 9196.770143,
# day 99, sell 1 unit at price 820.919983, investment 0.796875 %, total balance 10017.690126,
# day 111: buy 1 unit at price 823.559998, total balance 9194.130128
# day 112, sell 1 unit at price 837.169983, investment 1.652580 %, total balance 10031.300111,
# day 113: buy 1 unit at price 836.820007, total balance 9194.480104
# day 114, sell 1 unit at price 838.210022, investment 0.166107 %, total balance 10032.690126,
# day 116: buy 1 unit at price 843.190002, total balance 9189.500124
# day 117, sell 1 unit at price 862.760010, investment 2.320949 %, total balance 10052.260134,
# day 144: buy 1 unit at price 966.950012, total balance 9085.310122
# day 145, sell 1 unit at price 975.599976, investment 0.894562 %, total balance 10060.910098,
# day 156: buy 1 unit at price 957.369995, total balance 9103.540103
# day 157, sell 1 unit at price 950.630005, investment -0.704011 %, total balance 10054.170108,
# day 160: buy 1 unit at price 965.590027, total balance 9088.580081
# day 161, sell 1 unit at price 952.270020, investment -1.379468 %, total balance 10040.850101,
# day 163: buy 1 unit at price 940.489990, total balance 9100.360111
# day 166, sell 1 unit at price 898.700012, investment -4.443426 %, total balance 9999.060123,
# day 169: buy 1 unit at price 918.590027, total balance 9080.470096
# day 170, sell 1 unit at price 928.799988, investment 1.111482 %, total balance 10009.270084,
# day 171: buy 1 unit at price 930.090027, total balance 9079.180057
# day 172, sell 1 unit at price 943.830017, investment 1.477275 %, total balance 10023.010074,
# day 185: buy 1 unit at price 930.500000, total balance 9092.510074
# day 187, sell 1 unit at price 930.390015, investment -0.011820 %, total balance 10022.900089,
# day 192: buy 1 unit at price 922.900024, total balance 9100.000065
# day 194, sell 1 unit at price 914.390015, investment -0.922094 %, total balance 10014.390080,
# day 195: buy 1 unit at price 922.669983, total balance 9091.720097
# day 196, sell 1 unit at price 922.219971, investment -0.048773 %, total balance 10013.940068,
# day 214: buy 1 unit at price 929.080017, total balance 9084.860051
# day 215: buy 1 unit at price 932.070007, total balance 8152.790044
# day 216, sell 1 unit at price 935.090027, investment 0.646878 %, total balance 9087.880071,
# day 217: buy 1 unit at price 925.109985, total balance 8162.770086
# day 218, sell 1 unit at price 920.289978, investment -1.263857 %, total balance 9083.060064,
# day 219, sell 1 unit at price 915.000000, investment -1.092841 %, total balance 9998.060064,
# day 221: buy 1 unit at price 931.580017, total balance 9066.480047
# day 222: buy 1 unit at price 932.450012, total balance 8134.030035
# day 223, sell 1 unit at price 928.530029, investment -0.327399 %, total balance 9062.560064,
# day 224, sell 1 unit at price 920.969971, investment -1.231170 %, total balance 9983.530035,
# day 236: buy 1 unit at price 989.250000, total balance 8994.280035
# day 237: buy 1 unit at price 987.830017, total balance 8006.450018
# day 238: buy 1 unit at price 989.679993, total balance 7016.770025
# day 239, sell 1 unit at price 992.000000, investment 0.277988 %, total balance 8008.770025,
# day 240, sell 1 unit at price 992.179993, investment 0.440357 %, total balance 9000.950018,
# day 241, sell 1 unit at price 992.809998, investment 0.316264 %, total balance 9993.760016,
# day 242: buy 1 unit at price 984.450012, total balance 9009.310004
# day 243, sell 1 unit at price 988.200012, investment 0.380923 %, total balance 9997.510016,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
