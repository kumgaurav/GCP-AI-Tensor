# %% [markdown]
# ## Q-Learning

# %% [markdown]
# Q-learning is a model-free reinforcement learning algorithm to learn the value of an action in a particular state. It does not require a model of the environment (hence "model-free"), and it can handle problems with stochastic transitions and rewards without requiring adaptations.
#
# For any finite Markov decision process (FMDP), Q-learning finds an optimal policy in the sense of maximizing the expected value of the total reward over any and all successive steps, starting from the current state.[1] Q-learning can identify an optimal action-selection policy for any given FMDP, given infinite exploration time and a partly-random policy.[1] "Q" refers to the function that the algorithm computes – the expected rewards for an action taken in a given state.[2]

# %% [markdown]
# Reinforcement Learning (RL) is one of the learning paradigms in machine learning that learns an optimal policy mapping states to actions by interacting with an environment to achieve the goal. In this article, I will introduce the two most commonly used RL algorithm: Q-Learning and SARSA.
# Similar to the Monte Carlo Algorithm (MC), Q-Learning and SARSA algorithms are also model-free RL algorithms that do not use the transition probability distribution associated with Markov Decision Process (MDP). Instead, they learn the optimal policy from experience. The main difference between MC and Q-Learning or SARSA algorithm is that MC needs to sample…

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
tf.compat.v1.disable_eager_execution()
sns.set()

# %%
df = pd.read_csv('/Users/gkumargaur/workspace/python/gitprojects/Stock-Prediction-Models/dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2020-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2020-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2020-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2020-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2020-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
from collections import deque
import random


class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen = 1000)
        self.inventory = []

        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999

        tf.compat.v1.reset_default_graph()
        self.sess = tf.compat.v1.InteractiveSession()
        self.X = tf.compat.v1.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.compat.v1.placeholder(tf.float32, [None, self.action_size])
        feed = tf.compat.v1.layers.dense(self.X, 256, activation = tf.nn.relu)
        self.logits = tf.compat.v1.layers.dense(feed, self.action_size)
        self.cost = tf.reduce_mean(input_tensor=tf.square(self.Y - self.logits))
        self.optimizer = tf.compat.v1.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        self.sess.run(tf.compat.v1.global_variables_initializer())

    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0]
        )

    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def replay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost

    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)

            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))


            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )

            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest

    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)

                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]

                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]

                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest,
                                    next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip, 
              batch_size = batch_size)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# /Users/gkumargaur/opt/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow/python/keras/legacy_tf_layers/core.py:171: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   warnings.warn('`tf.layers.dense` is deprecated and '
# /Users/gkumargaur/opt/miniconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1692: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# epoch: 10, total rewards: 1408.164734.3, cost: 0.974758, total money: 6624.014710
# epoch: 20, total rewards: 1419.674743.3, cost: 0.772271, total money: 7626.054748
# epoch: 30, total rewards: 1313.184694.3, cost: 0.511918, total money: 4713.484682
# epoch: 40, total rewards: 1419.734681.3, cost: 0.375595, total money: 5746.534669
# epoch: 50, total rewards: 1641.324649.3, cost: 0.239536, total money: 9755.004642
# epoch: 60, total rewards: 1647.744691.3, cost: 0.234147, total money: 5091.424684
# epoch: 70, total rewards: 1716.284670.3, cost: 0.164743, total money: 7990.124636
# epoch: 80, total rewards: 1514.364688.3, cost: 0.130152, total money: 8723.294681
# epoch: 90, total rewards: 1393.834720.3, cost: 0.105611, total money: 9517.764713
# epoch: 100, total rewards: 1542.484683.3, cost: 0.086469, total money: 9666.414676
# epoch: 110, total rewards: 1522.744693.3, cost: 0.081808, total money: 10578.254703
# epoch: 120, total rewards: 1522.764651.3, cost: 0.062780, total money: 9646.694644
# epoch: 130, total rewards: 1405.474612.3, cost: 0.061055, total money: 7625.154605
# epoch: 140, total rewards: 1532.384585.3, cost: 0.060637, total money: 8696.554568
# epoch: 150, total rewards: 1601.184695.3, cost: 0.041317, total money: 9754.604678
# epoch: 160, total rewards: 1617.884707.3, cost: 0.047699, total money: 6902.474673
# epoch: 170, total rewards: 1630.684755.3, cost: 0.043356, total money: 6915.274721
# epoch: 180, total rewards: 1383.654666.3, cost: 0.281795, total money: 8547.824649
# epoch: 190, total rewards: 1249.544742.3, cost: 0.031127, total money: 8384.224735
# epoch: 200, total rewards: 1611.184634.3, cost: 0.073600, total money: 7833.914615

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 1: buy 1 unit at price 762.130005, total balance 9237.869995
# day 2: buy 1 unit at price 762.020020, total balance 8475.849975
# day 3: buy 1 unit at price 782.520020, total balance 7693.329955
# day 4, sell 1 unit at price 790.510010, investment 3.723775 %, total balance 8483.839965,
# day 5: buy 1 unit at price 785.309998, total balance 7698.529967
# day 6: buy 1 unit at price 762.559998, total balance 6935.969969
# day 7: buy 1 unit at price 754.020020, total balance 6181.949949
# day 8: buy 1 unit at price 736.080017, total balance 5445.869932
# day 9: buy 1 unit at price 758.489990, total balance 4687.379942
# day 10, sell 1 unit at price 764.479980, investment 0.322821 %, total balance 5451.859922,
# day 11: buy 1 unit at price 771.229980, total balance 4680.629942
# day 13: buy 1 unit at price 769.200012, total balance 3911.429930
# day 15, sell 1 unit at price 760.989990, investment -2.751371 %, total balance 4672.419920,
# day 16: buy 1 unit at price 761.679993, total balance 3910.739927
# day 17, sell 1 unit at price 768.239990, investment -2.173665 %, total balance 4678.979917,
# day 18: buy 1 unit at price 770.840027, total balance 3908.139890
# day 19, sell 1 unit at price 758.039978, investment -0.592743 %, total balance 4666.179868,
# day 20: buy 1 unit at price 747.919983, total balance 3918.259885
# day 21: buy 1 unit at price 750.500000, total balance 3167.759885
# day 22: buy 1 unit at price 762.520020, total balance 2405.239865
# day 24: buy 1 unit at price 771.190002, total balance 1634.049863
# day 25: buy 1 unit at price 776.419983, total balance 857.629880
# day 27, sell 1 unit at price 789.270020, investment 4.674942 %, total balance 1646.899900,
# day 28, sell 1 unit at price 796.099976, investment 8.153999 %, total balance 2442.999876,
# day 32, sell 1 unit at price 794.200012, investment 4.708041 %, total balance 3237.199888,
# day 34, sell 1 unit at price 794.559998, investment 3.025040 %, total balance 4031.759886,
# day 35: buy 1 unit at price 791.260010, total balance 3240.499876
# day 36, sell 1 unit at price 789.909973, investment 2.692403 %, total balance 4030.409849,
# day 39: buy 1 unit at price 782.789978, total balance 3247.619871
# day 40: buy 1 unit at price 771.820007, total balance 2475.799864
# day 41, sell 1 unit at price 786.140015, investment 3.211325 %, total balance 3261.939879,
# day 42, sell 1 unit at price 786.900024, investment 2.083441 %, total balance 4048.839903,
# day 45: buy 1 unit at price 806.650024, total balance 3242.189879
# day 46: buy 1 unit at price 804.789978, total balance 2437.399901
# day 47: buy 1 unit at price 807.909973, total balance 1629.489928
# day 48: buy 1 unit at price 806.359985, total balance 823.129943
# day 49: buy 1 unit at price 807.880005, total balance 15.249938
# day 51, sell 1 unit at price 806.070007, investment 7.774899 %, total balance 821.319945,
# day 53, sell 1 unit at price 805.020020, investment 7.264493 %, total balance 1626.339965,
# day 55, sell 1 unit at price 823.869995, investment 8.045687 %, total balance 2450.209960,
# day 57, sell 1 unit at price 832.150024, investment 7.904670 %, total balance 3282.359984,
# day 58: buy 1 unit at price 823.309998, total balance 2459.049986
# day 59: buy 1 unit at price 802.320007, total balance 1656.729979
# day 61: buy 1 unit at price 795.695007, total balance 861.034972
# day 62: buy 1 unit at price 798.530029, total balance 62.504943
# day 64, sell 1 unit at price 801.340027, investment 3.209609 %, total balance 863.844970,
# day 65, sell 1 unit at price 806.969971, investment 1.985436 %, total balance 1670.814941,
# day 66, sell 1 unit at price 808.380005, investment 3.269080 %, total balance 2479.194946,
# day 67, sell 1 unit at price 809.559998, investment 4.889740 %, total balance 3288.754944,
# day 68, sell 1 unit at price 813.669983, investment 0.870261 %, total balance 4102.424927,
# day 70, sell 1 unit at price 820.450012, investment 1.945854 %, total balance 4922.874939,
# day 72, sell 1 unit at price 824.159973, investment 2.011363 %, total balance 5747.034912,
# day 74: buy 1 unit at price 831.659973, total balance 4915.374939
# day 75: buy 1 unit at price 830.760010, total balance 4084.614929
# day 76: buy 1 unit at price 831.330017, total balance 3253.284912
# day 77, sell 1 unit at price 828.640015, investment 2.763038 %, total balance 4081.924927,
# day 79, sell 1 unit at price 823.210022, investment 1.897561 %, total balance 4905.134949,
# day 81, sell 1 unit at price 830.630005, investment 0.889095 %, total balance 5735.764954,
# day 84: buy 1 unit at price 831.909973, total balance 4903.854981
# day 85: buy 1 unit at price 835.369995, total balance 4068.484986
# day 86: buy 1 unit at price 838.679993, total balance 3229.804993
# day 87: buy 1 unit at price 843.250000, total balance 2386.554993
# day 88, sell 1 unit at price 845.539978, investment 5.386874 %, total balance 3232.094971,
# day 89: buy 1 unit at price 845.619995, total balance 2386.474976
# day 90, sell 1 unit at price 847.200012, investment 6.472958 %, total balance 3233.674988,
# day 93: buy 1 unit at price 848.400024, total balance 2385.274964
# day 94: buy 1 unit at price 830.460022, total balance 1554.814942
# day 95: buy 1 unit at price 829.590027, total balance 725.224915
# day 96, sell 1 unit at price 817.580017, investment 2.385632 %, total balance 1542.804932,
# day 97, sell 1 unit at price 814.429993, investment -2.071758 %, total balance 2357.234925,
# day 99, sell 1 unit at price 820.919983, investment -1.184461 %, total balance 3178.154908,
# day 100: buy 1 unit at price 831.409973, total balance 2346.744935
# day 101, sell 1 unit at price 831.500000, investment 0.020447 %, total balance 3178.244935,
# day 102: buy 1 unit at price 829.559998, total balance 2348.684937
# day 103, sell 1 unit at price 838.549988, investment 0.798165 %, total balance 3187.234925,
# day 105: buy 1 unit at price 831.409973, total balance 2355.824952
# day 107: buy 1 unit at price 824.669983, total balance 1531.154969
# day 108: buy 1 unit at price 824.729980, total balance 706.424989
# day 109, sell 1 unit at price 823.349976, investment -1.438886 %, total balance 1529.774965,
# day 110, sell 1 unit at price 824.320007, investment -1.712213 %, total balance 2354.094972,
# day 111, sell 1 unit at price 823.559998, investment -2.335014 %, total balance 3177.654970,
# day 112, sell 1 unit at price 837.169983, investment -0.999268 %, total balance 4014.824953,
# day 116, sell 1 unit at price 843.190002, investment -0.614100 %, total balance 4858.014955,
# day 118, sell 1 unit at price 872.299988, investment 5.038167 %, total balance 5730.314943,
# day 119: buy 1 unit at price 871.729980, total balance 4858.584963
# day 120, sell 1 unit at price 874.250000, investment 5.383379 %, total balance 5732.834963,
# day 121, sell 1 unit at price 905.960022, investment 8.966701 %, total balance 6638.794985,
# day 122, sell 1 unit at price 912.570007, investment 10.006511 %, total balance 7551.364992,
# day 123, sell 1 unit at price 916.440002, investment 10.227208 %, total balance 8467.804994,
# day 124, sell 1 unit at price 927.039978, investment 12.413450 %, total balance 9394.844972,
# day 125, sell 1 unit at price 931.659973, investment 12.965455 %, total balance 10326.504945,
# day 127, sell 1 unit at price 934.299988, investment 7.177682 %, total balance 11260.804933,
# day 129: buy 1 unit at price 928.780029, total balance 10332.024904
# day 131, sell 1 unit at price 932.219971, investment 0.370372 %, total balance 11264.244875,
# day 133: buy 1 unit at price 943.000000, total balance 10321.244875
# day 137: buy 1 unit at price 941.859985, total balance 9379.384890
# day 139: buy 1 unit at price 954.960022, total balance 8424.424868
# day 141, sell 1 unit at price 971.469971, investment 3.019085 %, total balance 9395.894839,
# day 142: buy 1 unit at price 975.880005, total balance 8420.014834
# day 143, sell 1 unit at price 964.859985, investment 2.441977 %, total balance 9384.874819,
# day 145, sell 1 unit at price 975.599976, investment 2.161342 %, total balance 10360.474795,
# day 146, sell 1 unit at price 983.679993, investment 0.799277 %, total balance 11344.154788,
# day 148: buy 1 unit at price 980.940002, total balance 10363.214786
# day 150: buy 1 unit at price 949.830017, total balance 9413.384769
# day 151: buy 1 unit at price 942.900024, total balance 8470.484745
# day 152, sell 1 unit at price 953.400024, investment -2.807509 %, total balance 9423.884769,
# day 153: buy 1 unit at price 950.760010, total balance 8473.124759
# day 156, sell 1 unit at price 957.369995, investment 0.793824 %, total balance 9430.494754,
# day 160: buy 1 unit at price 965.590027, total balance 8464.904727
# day 161: buy 1 unit at price 952.270020, total balance 7512.634707
# day 162: buy 1 unit at price 927.330017, total balance 6585.304690
# day 164: buy 1 unit at price 917.789978, total balance 5667.514712
# day 165: buy 1 unit at price 908.729980, total balance 4758.784732
# day 167: buy 1 unit at price 911.710022, total balance 3847.074710
# day 168, sell 1 unit at price 906.690002, investment -3.840282 %, total balance 4753.764712,
# day 169: buy 1 unit at price 918.590027, total balance 3835.174685
# day 170, sell 1 unit at price 928.799988, investment -2.309733 %, total balance 4763.974673,
# day 171, sell 1 unit at price 930.090027, investment -3.676509 %, total balance 5694.064700,
# day 172: buy 1 unit at price 943.830017, total balance 4750.234683
# day 173, sell 1 unit at price 947.159973, investment -0.536617 %, total balance 5697.394656,
# day 174: buy 1 unit at price 955.989990, total balance 4741.404666
# day 176: buy 1 unit at price 965.400024, total balance 3776.004642
# day 177: buy 1 unit at price 970.890015, total balance 2805.114627
# day 178: buy 1 unit at price 968.150024, total balance 1836.964603
# day 179: buy 1 unit at price 972.919983, total balance 864.044620
# day 180, sell 1 unit at price 980.340027, investment 5.716413 %, total balance 1844.384647,
# day 181: buy 1 unit at price 950.700012, total balance 893.684635
# day 182, sell 1 unit at price 947.799988, investment 3.269812 %, total balance 1841.484623,
# day 183, sell 1 unit at price 934.090027, investment 2.790713 %, total balance 2775.574650,
# day 184, sell 1 unit at price 941.530029, investment 3.270778 %, total balance 3717.104679,
# day 186, sell 1 unit at price 930.830017, investment 1.332476 %, total balance 4647.934696,
# day 187: buy 1 unit at price 930.390015, total balance 3717.544681
# day 188, sell 1 unit at price 923.650024, investment -2.138096 %, total balance 4641.194705,
# day 189: buy 1 unit at price 927.960022, total balance 3713.234683
# day 190, sell 1 unit at price 929.359985, investment -2.785595 %, total balance 4642.594668,
# day 192: buy 1 unit at price 922.900024, total balance 3719.694644
# day 193: buy 1 unit at price 907.239990, total balance 2812.454654
# day 194, sell 1 unit at price 914.390015, investment -5.283821 %, total balance 3726.844669,
# day 195: buy 1 unit at price 922.669983, total balance 2804.174686
# day 196: buy 1 unit at price 922.219971, total balance 1881.954715
# day 198: buy 1 unit at price 910.979980, total balance 970.974735
# day 199: buy 1 unit at price 910.669983, total balance 60.304752
# day 201, sell 1 unit at price 924.690002, investment -4.758522 %, total balance 984.994754,
# day 203, sell 1 unit at price 921.280029, investment -4.841191 %, total balance 1906.274783,
# day 205: buy 1 unit at price 913.809998, total balance 992.464785
# day 207, sell 1 unit at price 929.570007, investment -4.455657 %, total balance 1922.034792,
# day 208: buy 1 unit at price 939.330017, total balance 982.704775
# day 209: buy 1 unit at price 937.340027, total balance 45.364748
# day 212, sell 1 unit at price 935.950012, investment -1.551488 %, total balance 981.314760,
# day 213: buy 1 unit at price 926.500000, total balance 54.814760
# day 215, sell 1 unit at price 932.070007, investment 0.180569 %, total balance 986.884767,
# day 216: buy 1 unit at price 935.090027, total balance 51.794740
# day 218, sell 1 unit at price 920.289978, investment -0.826549 %, total balance 972.084718,
# day 219: buy 1 unit at price 915.000000, total balance 57.084718
# day 220, sell 1 unit at price 921.809998, investment -0.118109 %, total balance 978.894716,
# day 221: buy 1 unit at price 931.580017, total balance 47.314699
# day 225, sell 1 unit at price 924.859985, investment 1.942154 %, total balance 972.174684,
# day 226: buy 1 unit at price 944.489990, total balance 27.684694
# day 230, sell 1 unit at price 957.789978, investment 3.806344 %, total balance 985.474672,
# day 231, sell 1 unit at price 951.679993, investment 3.194468 %, total balance 1937.154665,
# day 232, sell 1 unit at price 969.960022, investment 6.474351 %, total balance 2907.114687,
# day 233, sell 1 unit at price 978.890015, investment 7.491191 %, total balance 3886.004702,
# day 235, sell 1 unit at price 972.599976, investment 6.433501 %, total balance 4858.604678,
# day 236: buy 1 unit at price 989.250000, total balance 3869.354678
# day 238, sell 1 unit at price 989.679993, investment 5.360201 %, total balance 4859.034671,
# day 239, sell 1 unit at price 992.000000, investment 5.831392 %, total balance 5851.034671,
# day 240, sell 1 unit at price 992.179993, investment 7.089044 %, total balance 6843.214664,
# day 249, sell 1 unit at price 1017.109985, investment 8.771343 %, total balance 7860.324649,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
